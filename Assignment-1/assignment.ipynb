# %% [markdown]
# # Machine Learning Assignment
# Synthetic Data & Supervised Learning

# %% [markdown]
# ## Instructions
# - Use NumPy, Pandas, Matplotlib, and scikit-learn.
# - Follow each task and fill in the code.
# - Hints are provided to guide you.
# - Use random seed = 42.

# %% [markdown]
# ## Task 1: Supervised Learning Overview
# Generate one regression dataset and one classification dataset.

# %% [markdown]
# **Hint:** Use sklearn.datasets.make_regression and make_classification.

# %%
from sklearn.datasets import make_regression, make_classification

# TODO: Generate datasets

# %% [markdown]
# ## Task 2: Linear Regression with Gradient Descent
# Generate y = 5x + 3 + noise and implement gradient descent.

# %% [markdown]
# **Hint:** Initialize weights randomly and update using gradient descent rule.

# %%
import numpy as np

# TODO: Generate x and y
# TODO: Implement gradient descent

# %% [markdown]
# ## Task 3: Polynomial Regression
# Fit both linear and polynomial regression.

# %% [markdown]
# **Hint:** Use PolynomialFeatures from sklearn.preprocessing.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# TODO: Generate nonlinear data
# TODO: Fit models

# %% [markdown]
# ## Task 4: Generalization
# Split dataset and compare simple vs complex model.

# %% [markdown]
# **Hint:** Use train_test_split and compare train/test error.

# %%
from sklearn.model_selection import train_test_split

# TODO: Split data
# TODO: Train models and compare

# %% [markdown]
# ## Task 5: Linear Classification
# Create linearly separable data and train classifier.

# %% [markdown]
# **Hint:** Use make_blobs for easy separable data.

# %%
from sklearn.datasets import make_blobs

# TODO: Generate data
# TODO: Train classifier

# %% [markdown]
# ## Task 6: Perceptron
# Train perceptron on same dataset.

# %% [markdown]
# **Hint:** Use sklearn.linear_model.Perceptron.

# %%
from sklearn.linear_model import Perceptron

# TODO: Train perceptron

# %% [markdown]
# ## Task 7: Logistic Regression
# Train logistic regression on overlapping data.

# %% [markdown]
# **Hint:** Use LogisticRegression from sklearn.

# %%
from sklearn.linear_model import LogisticRegression

# TODO: Train logistic regression

# %% [markdown]
# ## Task 8: KNN
# Use nonlinear dataset (moons or circles).

# %% [markdown]
# **Hint:** Use make_moons or make_circles.

# %%
from sklearn.datasets import make_moons
from sklearn.neighbors import KNeighborsClassifier

# TODO: Generate data and train KNN

# %% [markdown]
# ## Task 9: Decision Tree
# Train decision tree on rule-based data.

# %% [markdown]
# **Hint:** Use DecisionTreeClassifier.

# %%
from sklearn.tree import DecisionTreeClassifier

# TODO: Generate rule-based data
# TODO: Train tree

# %% [markdown]
# ## Task 10: Random Forest
# Compare decision tree vs random forest.

# %% [markdown]
# **Hint:** Use RandomForestClassifier.

# %%
from sklearn.ensemble import RandomForestClassifier

# TODO: Train and compare models
